# %%
from utils.utils import load_domain_map, prepare_to_annotate,read_file_content

# %%
# Charger la map des domaines similaires
domain_map = load_domain_map("utils/domain_map.json")

# %%
# # Appel de la fonction avec chemins relatifs corrects
# prepare_to_annotate(
#     offers_path="../scraping/offres",
#     cvs_path="../scraping/cvs",
#     domain_map=domain_map,
#     output_path="ready_to_annotate.csv",cvs_per_offer=5
# )
# Out:
# 📂 Analyse des offres dans : ../scraping/offres
#
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 1 located at path: ../scraping/offres\AI_and_ML\AI Engineer_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 2 located at path: ../scraping/offres\AI_and_ML\AI Researcher_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 3 located at path: ../scraping/offres\AI_and_ML\Artificial Intelligence_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 4 located at path: ../scraping/offres\AI_and_ML\Computer Vision_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 5 located at path: ../scraping/offres\AI_and_ML\Data Scientist_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 6 located at path: ../scraping/offres\AI_and_ML\Deep Learning_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 7 located at path: ../scraping/offres\AI_and_ML\Machine Learning_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 8 located at path: ../scraping/offres\AI_and_ML\Natural Language Processing_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 9 located at path: ../scraping/offres\AI_and_ML\Neural Networks_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 10 located at path: ../scraping/offres\AI_and_ML\PyTorch_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 11 located at path: ../scraping/offres\AI_and_ML\Reinforcement Learning_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 12 located at path: ../scraping/offres\AI_and_ML\Supervised Learning_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 13 located at path: ../scraping/offres\AI_and_ML\TensorFlow_job_1.txt
# 🔎 CV selection summary for domain 'AI_and_ML': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 14 located at path: ../scraping/offres\AI_and_ML\Unsupervised Learning_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 15 located at path: ../scraping/offres\Blockchain\Bitcoin_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 16 located at path: ../scraping/offres\Blockchain\Blockchain Architect_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 17 located at path: ../scraping/offres\Blockchain\Blockchain Developer_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 18 located at path: ../scraping/offres\Blockchain\Blockchain Solutions_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 19 located at path: ../scraping/offres\Blockchain\Blockchain_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 20 located at path: ../scraping/offres\Blockchain\Cryptocurrency_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 21 located at path: ../scraping/offres\Blockchain\Cryptography_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 22 located at path: ../scraping/offres\Blockchain\DeFi_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 23 located at path: ../scraping/offres\Blockchain\Ethereum Developer_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 24 located at path: ../scraping/offres\Blockchain\Ethereum_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 25 located at path: ../scraping/offres\Blockchain\NFTs_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 26 located at path: ../scraping/offres\Blockchain\Smart Contracts_job_1.txt
# 🔎 CV selection summary for domain 'Blockchain': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 27 located at path: ../scraping/offres\Blockchain\Solidity_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 28 located at path: ../scraping/offres\Cloud_Computing\Ansible_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 29 located at path: ../scraping/offres\Cloud_Computing\AWS_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 30 located at path: ../scraping/offres\Cloud_Computing\Azure_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 31 located at path: ../scraping/offres\Cloud_Computing\CI CD_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 32 located at path: ../scraping/offres\Cloud_Computing\Cloud Architecture_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 33 located at path: ../scraping/offres\Cloud_Computing\Cloud DevOps_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 34 located at path: ../scraping/offres\Cloud_Computing\Cloud Engineering_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 35 located at path: ../scraping/offres\Cloud_Computing\Cloud Security_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 36 located at path: ../scraping/offres\Cloud_Computing\DevOps_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 37 located at path: ../scraping/offres\Cloud_Computing\Docker_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 38 located at path: ../scraping/offres\Cloud_Computing\Google Cloud_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 39 located at path: ../scraping/offres\Cloud_Computing\Kubernetes_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 40 located at path: ../scraping/offres\Cloud_Computing\Serverless_job_1.txt
# 🔎 CV selection summary for domain 'Cloud_Computing': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 41 located at path: ../scraping/offres\Cloud_Computing\Terraform_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 42 located at path: ../scraping/offres\Cybersecurity\Cryptography_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 43 located at path: ../scraping/offres\Cybersecurity\Cybersecurity_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 44 located at path: ../scraping/offres\Cybersecurity\Ethical Hacking_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 45 located at path: ../scraping/offres\Cybersecurity\Firewall_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 46 located at path: ../scraping/offres\Cybersecurity\Incident Response_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 47 located at path: ../scraping/offres\Cybersecurity\Malware_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 48 located at path: ../scraping/offres\Cybersecurity\Network Defense_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 49 located at path: ../scraping/offres\Cybersecurity\Network Security_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 50 located at path: ../scraping/offres\Cybersecurity\Penetration Testing_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 51 located at path: ../scraping/offres\Cybersecurity\Ransomware_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 52 located at path: ../scraping/offres\Cybersecurity\Risk Management_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 53 located at path: ../scraping/offres\Cybersecurity\Security Operations Center_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 54 located at path: ../scraping/offres\Cybersecurity\SIEM_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 55 located at path: ../scraping/offres\Cybersecurity\SOC Analyst_job_1.txt
# 🔎 CV selection summary for domain 'Cybersecurity': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 56 located at path: ../scraping/offres\Cybersecurity\Vulnerability Assessment_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 57 located at path: ../scraping/offres\Database_Administration\Data Backup_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 58 located at path: ../scraping/offres\Database_Administration\Data Migration_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 59 located at path: ../scraping/offres\Database_Administration\Data Recovery_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 60 located at path: ../scraping/offres\Database_Administration\Database Administration_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 61 located at path: ../scraping/offres\Database_Administration\Database Design_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 62 located at path: ../scraping/offres\Database_Administration\Database Performance Tuning_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 63 located at path: ../scraping/offres\Database_Administration\Database Security_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 64 located at path: ../scraping/offres\Database_Administration\MongoDB_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 65 located at path: ../scraping/offres\Database_Administration\MySQL_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 66 located at path: ../scraping/offres\Database_Administration\NoSQL_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 67 located at path: ../scraping/offres\Database_Administration\Oracle_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 68 located at path: ../scraping/offres\Database_Administration\PostgreSQL_job_1.txt
# 🔎 CV selection summary for domain 'Database_Administration': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 69 located at path: ../scraping/offres\Database_Administration\SQL_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 70 located at path: ../scraping/offres\Data_Engineering\Apache Spark_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 71 located at path: ../scraping/offres\Data_Engineering\Big Data_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 72 located at path: ../scraping/offres\Data_Engineering\Data Engineering_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 73 located at path: ../scraping/offres\Data_Engineering\Data Lakes_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 74 located at path: ../scraping/offres\Data_Engineering\Data Modeling_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 75 located at path: ../scraping/offres\Data_Engineering\Data Pipeline_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 76 located at path: ../scraping/offres\Data_Engineering\Data Warehousing_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 77 located at path: ../scraping/offres\Data_Engineering\ETL_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 78 located at path: ../scraping/offres\Data_Engineering\Hadoop_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 79 located at path: ../scraping/offres\Data_Engineering\Kafka_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 80 located at path: ../scraping/offres\Data_Engineering\NoSQL_job_1.txt
# 🔎 CV selection summary for domain 'Data_Engineering': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 81 located at path: ../scraping/offres\Data_Engineering\SQL_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 82 located at path: ../scraping/offres\Data_Science\AI_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 83 located at path: ../scraping/offres\Data_Science\Big Data_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 84 located at path: ../scraping/offres\Data_Science\Data Analyst_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 85 located at path: ../scraping/offres\Data_Science\Data Engineer_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 86 located at path: ../scraping/offres\Data_Science\Data Mining_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 87 located at path: ../scraping/offres\Data_Science\Data Science_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 88 located at path: ../scraping/offres\Data_Science\Deep Learning_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 89 located at path: ../scraping/offres\Data_Science\Hadoop_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 90 located at path: ../scraping/offres\Data_Science\Keras_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 91 located at path: ../scraping/offres\Data_Science\Machine Learning_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 92 located at path: ../scraping/offres\Data_Science\Matplotlib_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 93 located at path: ../scraping/offres\Data_Science\NoSQL_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 94 located at path: ../scraping/offres\Data_Science\Numpy_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 95 located at path: ../scraping/offres\Data_Science\Pandas_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 96 located at path: ../scraping/offres\Data_Science\Python Data Science_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 97 located at path: ../scraping/offres\Data_Science\R_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 98 located at path: ../scraping/offres\Data_Science\Scikit-learn_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 99 located at path: ../scraping/offres\Data_Science\Seaborn_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 100 located at path: ../scraping/offres\Data_Science\Spark_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 101 located at path: ../scraping/offres\Data_Science\SQL_job_1.txt
# 🔎 CV selection summary for domain 'Data_Science': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 102 located at path: ../scraping/offres\Data_Science\TensorFlow_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 103 located at path: ../scraping/offres\DevOps\Ansible_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 104 located at path: ../scraping/offres\DevOps\AWS Lambda_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 105 located at path: ../scraping/offres\DevOps\AWS_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 106 located at path: ../scraping/offres\DevOps\Azure_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 107 located at path: ../scraping/offres\DevOps\Bash_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 108 located at path: ../scraping/offres\DevOps\CI CD_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 109 located at path: ../scraping/offres\DevOps\Cloud Automation_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 110 located at path: ../scraping/offres\DevOps\DevOps_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 111 located at path: ../scraping/offres\DevOps\Docker_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 112 located at path: ../scraping/offres\DevOps\GitHub_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 113 located at path: ../scraping/offres\DevOps\Git_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 114 located at path: ../scraping/offres\DevOps\Infrastructure as Code_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 115 located at path: ../scraping/offres\DevOps\Jenkins_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 116 located at path: ../scraping/offres\DevOps\Kubernetes_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 117 located at path: ../scraping/offres\DevOps\Linux_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 118 located at path: ../scraping/offres\DevOps\Shell Scripting_job_1.txt
# 🔎 CV selection summary for domain 'DevOps': 2 same, 1 similar, 2 different, 0 extra → Total: 5
# 📌 5 CVs added for offer 119 located at path: ../scraping/offres\DevOps\Terraform_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 120 located at path: ../scraping/offres\Game_Development\3D Modeling_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 121 located at path: ../scraping/offres\Game_Development\AR Development_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 122 located at path: ../scraping/offres\Game_Development\C#_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 123 located at path: ../scraping/offres\Game_Development\C++_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 124 located at path: ../scraping/offres\Game_Development\Game AI_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 125 located at path: ../scraping/offres\Game_Development\Game Design_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 126 located at path: ../scraping/offres\Game_Development\Game Physics_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 127 located at path: ../scraping/offres\Game_Development\Game Programming_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 128 located at path: ../scraping/offres\Game_Development\Game Testing_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 129 located at path: ../scraping/offres\Game_Development\Mobile Game Development_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 130 located at path: ../scraping/offres\Game_Development\Unity_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 131 located at path: ../scraping/offres\Game_Development\Unreal Engine_job_1.txt
# 🔎 CV selection summary for domain 'Game_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 132 located at path: ../scraping/offres\Game_Development\VR Development_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 133 located at path: ../scraping/offres\IoT\Arduino_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 134 located at path: ../scraping/offres\IoT\Automation_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 135 located at path: ../scraping/offres\IoT\Edge Computing_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 136 located at path: ../scraping/offres\IoT\Embedded Systems_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 137 located at path: ../scraping/offres\IoT\Internet of Things_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 138 located at path: ../scraping/offres\IoT\IoT Platforms_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 139 located at path: ../scraping/offres\IoT\IoT Security_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 140 located at path: ../scraping/offres\IoT\IoT_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 141 located at path: ../scraping/offres\IoT\Raspberry Pi_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 142 located at path: ../scraping/offres\IoT\Sensor Networks_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 143 located at path: ../scraping/offres\IoT\Smart Devices_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 144 located at path: ../scraping/offres\IoT\Smart Home_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 145 located at path: ../scraping/offres\IoT\Wearables_job_1.txt
# 🔎 CV selection summary for domain 'IoT': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 146 located at path: ../scraping/offres\IoT\Wireless Networks_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 147 located at path: ../scraping/offres\Mobile_Development\Android Development_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 148 located at path: ../scraping/offres\Mobile_Development\Android Studio_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 149 located at path: ../scraping/offres\Mobile_Development\Android_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 150 located at path: ../scraping/offres\Mobile_Development\App Development_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 151 located at path: ../scraping/offres\Mobile_Development\Flutter_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 152 located at path: ../scraping/offres\Mobile_Development\iOS Development_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 153 located at path: ../scraping/offres\Mobile_Development\iOS_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 154 located at path: ../scraping/offres\Mobile_Development\Kotlin_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 155 located at path: ../scraping/offres\Mobile_Development\Mobile Apps_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 156 located at path: ../scraping/offres\Mobile_Development\Mobile UX_UI_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 157 located at path: ../scraping/offres\Mobile_Development\React Native_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 158 located at path: ../scraping/offres\Mobile_Development\Swift_job_1.txt
# 🔎 CV selection summary for domain 'Mobile_Development': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 159 located at path: ../scraping/offres\Mobile_Development\Xcode_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 160 located at path: ../scraping/offres\Networking\Cisco_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 161 located at path: ../scraping/offres\Networking\Firewall_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 162 located at path: ../scraping/offres\Networking\Juniper_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 163 located at path: ../scraping/offres\Networking\LAN_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 164 located at path: ../scraping/offres\Networking\Network Administration_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 165 located at path: ../scraping/offres\Networking\Network Architect_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 166 located at path: ../scraping/offres\Networking\Network Design_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 167 located at path: ../scraping/offres\Networking\Network Engineer_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 168 located at path: ../scraping/offres\Networking\Network Monitoring_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 169 located at path: ../scraping/offres\Networking\Network Performance_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 170 located at path: ../scraping/offres\Networking\Network Protocols_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 171 located at path: ../scraping/offres\Networking\Network Security_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 172 located at path: ../scraping/offres\Networking\Network Troubleshooting_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 173 located at path: ../scraping/offres\Networking\Networking_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 174 located at path: ../scraping/offres\Networking\Routing_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 175 located at path: ../scraping/offres\Networking\Switching_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 176 located at path: ../scraping/offres\Networking\TCP_IP_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 177 located at path: ../scraping/offres\Networking\VPN_job_1.txt
# 🔎 CV selection summary for domain 'Networking': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 178 located at path: ../scraping/offres\Networking\WAN_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 179 located at path: ../scraping/offres\Software_Development\Angular_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 180 located at path: ../scraping/offres\Software_Development\C#_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 181 located at path: ../scraping/offres\Software_Development\C++_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 182 located at path: ../scraping/offres\Software_Development\CI CD_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 183 located at path: ../scraping/offres\Software_Development\DevOps_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 184 located at path: ../scraping/offres\Software_Development\Django_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 185 located at path: ../scraping/offres\Software_Development\Flask_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 186 located at path: ../scraping/offres\Software_Development\Git_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 187 located at path: ../scraping/offres\Software_Development\Go_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 188 located at path: ../scraping/offres\Software_Development\JavaScript_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 189 located at path: ../scraping/offres\Software_Development\Java_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 190 located at path: ../scraping/offres\Software_Development\Kotlin_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 191 located at path: ../scraping/offres\Software_Development\Laravel_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 192 located at path: ../scraping/offres\Software_Development\Node.js_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 193 located at path: ../scraping/offres\Software_Development\Python Software Development_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 194 located at path: ../scraping/offres\Software_Development\React_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 195 located at path: ../scraping/offres\Software_Development\Rust_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 196 located at path: ../scraping/offres\Software_Development\Spring_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 197 located at path: ../scraping/offres\Software_Development\Swift_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 198 located at path: ../scraping/offres\Software_Development\Symfony_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 199 located at path: ../scraping/offres\Software_Development\TDD_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 200 located at path: ../scraping/offres\Software_Development\TypeScript_job_1.txt
# 🔎 CV selection summary for domain 'Software_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 201 located at path: ../scraping/offres\Software_Development\Vue.js_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 202 located at path: ../scraping/offres\Technical_Support\Active Directory_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 203 located at path: ../scraping/offres\Technical_Support\Customer Support_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 204 located at path: ../scraping/offres\Technical_Support\Help Desk_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 205 located at path: ../scraping/offres\Technical_Support\IT Support_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 206 located at path: ../scraping/offres\Technical_Support\Linux Server_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 207 located at path: ../scraping/offres\Technical_Support\Network Troubleshooting_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 208 located at path: ../scraping/offres\Technical_Support\Remote Support_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 209 located at path: ../scraping/offres\Technical_Support\Technical Documentation_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 210 located at path: ../scraping/offres\Technical_Support\Technical Support_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 211 located at path: ../scraping/offres\Technical_Support\Ticketing Systems_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 212 located at path: ../scraping/offres\Technical_Support\Troubleshooting_job_1.txt
# 🔎 CV selection summary for domain 'Technical_Support': 0 same, 1 similar, 2 different, 2 extra → Total: 5
# 📌 5 CVs added for offer 213 located at path: ../scraping/offres\Technical_Support\Windows Server_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 214 located at path: ../scraping/offres\Web_Development\Angular_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 215 located at path: ../scraping/offres\Web_Development\CSS_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 216 located at path: ../scraping/offres\Web_Development\Django_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 217 located at path: ../scraping/offres\Web_Development\Express.js_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 218 located at path: ../scraping/offres\Web_Development\Flask_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 219 located at path: ../scraping/offres\Web_Development\GraphQL_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 220 located at path: ../scraping/offres\Web_Development\HTML_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 221 located at path: ../scraping/offres\Web_Development\JavaScript_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 222 located at path: ../scraping/offres\Web_Development\JQuery_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 223 located at path: ../scraping/offres\Web_Development\Laravel_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 224 located at path: ../scraping/offres\Web_Development\MongoDB_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 225 located at path: ../scraping/offres\Web_Development\Node.js_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 226 located at path: ../scraping/offres\Web_Development\PHP_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 227 located at path: ../scraping/offres\Web_Development\PostgreSQL_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 228 located at path: ../scraping/offres\Web_Development\React_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 229 located at path: ../scraping/offres\Web_Development\RESTful API_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 230 located at path: ../scraping/offres\Web_Development\Ruby on Rails_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 231 located at path: ../scraping/offres\Web_Development\Serverless_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 232 located at path: ../scraping/offres\Web_Development\SQL_job_1.txt
# 🔎 CV selection summary for domain 'Web_Development': 2 same, 0 similar, 2 different, 1 extra → Total: 5
# 📌 5 CVs added for offer 233 located at path: ../scraping/offres\Web_Development\Vue.js_job_1.txt

# %%
import os
import csv
import time
import random
from utils.utils import read_file_content
from utils.deepseek import get_deepseek_score
from utils.groq import get_groq_score_with_retry
from dotenv import load_dotenv
# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
def annotate_data(input_path, output_path, max_annotations=None, api="deepseek"):
    # Read already annotated rows
    existing_rows = set()
    if os.path.exists(output_path):
        with open(output_path, 'r', encoding='utf-8') as f_out:
            reader = csv.reader(f_out)
            next(reader, None)  # Skip header
            for row in reader:
                if row:
                    existing_rows.add((row[0], row[1]))  # (offer_path, cv_path)

    with open(input_path, 'r', encoding='utf-8') as f_in:
        reader = csv.reader(f_in)
        header = next(reader)  # Skip input header

        # Open output file in append mode
        with open(output_path, 'a', newline='', encoding='utf-8') as f_out:
            writer = csv.writer(f_out)

            # Write header only if file was empty
            if os.stat(output_path).st_size == 0:
                writer.writerow(['offer_path', 'cv_path', 'score'])

            counter = len(existing_rows)  # Start counter from already annotated rows

            for row in reader:
                if max_annotations is not None and counter >= max_annotations:
                    print(f"🛑 Maximum of {max_annotations} annotations reached. Stopping.")
                    break

                offer_path, cv_path = row

                if (offer_path, cv_path) in existing_rows:
                    print(f"⏩ Skipping already annotated: {offer_path}, {cv_path}")
                    continue

                print("\n🔎 Offer:", offer_path)
                print("📝 CV:", cv_path)

                offer_text = read_file_content(offer_path)
                cv_text = read_file_content(cv_path)

                if not offer_text or not cv_text:
                    print(f"⚠️ Impossible de lire les fichiers : {offer_path}, {cv_path}")
                    continue

                try:
                    score = None
                    if api == "deepseek":
                        # Call the DeepSeek API to get the score
                        score = get_deepseek_score(offer_text, cv_text)
                    elif api == "groq":
                        # Call the Groq API to get the score
                        score = get_groq_score_with_retry(offer_text, cv_text)
                    print(f"✅ Score obtenu : {score}")
                    writer.writerow([offer_path, cv_path, score])
                    counter += 1

                    # Save after every 10 successful annotations
                    if counter % 5 == 0:
                        f_out.flush()
                        os.fsync(f_out.fileno())
                        print("💾 Progress saved.")

                    # Sleep randomly between 5 and 10 seconds to avoid API limits
                    time.sleep(random.uniform(10, 15))

                except Exception as e:
                    print(f"❌ Erreur lors de l’annotation : {e}")

# %%
annotate_data(input_path="ready_to_annotate.csv",output_path="annotated_data.csv",max_annotations=500)

# %%
import re
def safe_extract_score(score):
    try:
        # Extract the last float from the string
        matches = re.findall(r"[-+]?\d*\.\d+|\d+", str(score))
        if matches:
            return float(matches[-1])  # Take the last number found
        else:
            return None
    except Exception as e:
        print(f"Error parsing score: {score} -> {e}")
        return None

# %%
def reannotate_missing_scores(csv_path,api="deepseek"):
    temp_path = csv_path + '.tmp'

    with open(csv_path, 'r', encoding='utf-8') as f_in, open(temp_path, 'w', newline='', encoding='utf-8') as f_out:
        reader = csv.DictReader(f_in)
        fieldnames = reader.fieldnames
        writer = csv.DictWriter(f_out, fieldnames=fieldnames)
        writer.writeheader()

        for row in reader:
            offer_path = row['offer_path']
            cv_path = row['cv_path']
            score = row['score'].strip()

            # Handle missing score
            if not score or score.lower() == 'nan':
                print(f"🔄 Réannotation (score manquant) : {offer_path} + {cv_path}")

                offer_text = read_file_content(offer_path)
                cv_text = read_file_content(cv_path)

                if not offer_text or not cv_text:
                    print(f"⚠️ Impossible de lire les fichiers : {offer_path}, {cv_path}")
                    writer.writerow(row)  # Réécrit l'ancienne ligne inchangée
                    continue

                try:
                    new_score = None
                    if(api == "deepseek"):
                        # Call the DeepSeek API to get the score
                        new_score = get_deepseek_score(offer_text, cv_text)
                    elif(api == "groq"):
                        # Call the DeepSeek_2 API to get the score
                        new_score = get_groq_score(offer_text, cv_text)

                    print(f"✅ Nouveau score (via deepseek) : {new_score}")
                    row['score'] = new_score
                    time.sleep(random.uniform(2, 5))
                except Exception as e:
                    print(f"❌ Erreur lors de la réannotation : {e}")

            else:
                # Try to safely parse the score
                try:
                    float(score)  # Check if score is a valid float
                except ValueError:
                    print(f"⚙️ Nettoyage score invalide : {score} ({offer_path} + {cv_path})")
                    try:
                        cleaned_score = safe_extract_score(score)
                        print(f"✅ Score nettoyé : {cleaned_score}")
                        row['score'] = cleaned_score
                    except Exception as e:
                        print(f"❌ Erreur lors du nettoyage du score : {e}")
                        # Optional: you can decide to keep old score or mark as 0.0

            writer.writerow(row)

    # Remplacer l'ancien fichier par le nouveau
    os.replace(temp_path, csv_path)
    print("✅ Réannotation terminée et fichier mis à jour !")

# %%
reannotate_missing_scores(csv_path="annotated_data.csv")
# Out:
# ✅ Réannotation terminée et fichier mis à jour !

# %% [markdown]
# openRouter free trial end  for deepseek !!!!

# %% [markdown]
# ## test OLLAMA

# %%
from utils.ollama import get_mistral_score

# %%
offer = "Ingénieur IA spécialisé en vision par ordinateur et deep learning. Expérience en Python, PyTorch et traitement d’images requise."
cv = "Mohamed OUABBI, étudiant en ingénierie digitale, travaille sur l’OCR, YOLO, PyTorch et le deep learning."

score = get_mistral_score(offer, cv)

# %%
print("Score de similarité :", score)
# Out:
# Score de similarité : 0.95

# %% [markdown]
# ollama mistral give an amazing score but it's very slow !

# %% [markdown]
# ## try Firworks :

# %%
from utils.groq import get_groq_score

# %%
offer = "Ingénieur IA spécialisé en vision par ordinateur et deep learning. Expérience en Python, PyTorch et traitement d’images requise."
cv = "Mohamed OUABBI, étudiant en ingénierie digitale, travaille sur l’OCR, YOLO, PyTorch et le deep learning."

score = get_groq_score(offer, cv)

# %%
score
# Out:
# '0.7'

# %% [markdown]
# Groq is much better. While Ollama takes around 40 seconds for one matching, Groq completes it in just 0.5 seconds.

# %% [markdown]
# #### annotate with Groq

# %%
annotate_data(input_path="ready_to_annotate.csv",output_path="annotated_data2.csv",max_annotations=1000,api="groq")
# Out:
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Kubernetes_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_25.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Ansible_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_134.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\DevOps_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_42.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\RESTful API_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_25.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\GraphQL_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_22.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Ransomware_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_14.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Administration_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_1.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Computer Vision_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_74.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Google Cloud_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_164.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Performance_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_11.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Unsupervised Learning_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_9.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Data Analyst_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_162.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Kubernetes_job_1.txt, ../scraping/cvs\others\others_cv_326.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Infrastructure as Code_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_96.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Machine Learning_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_28.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\NFTs_job_1.txt, ../scraping/cvs\Blockchain\Blockchain_cv_4.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Reinforcement Learning_job_1.txt, ../scraping/cvs\others\others_cv_84.txt
# ⏩ Skipping already annotated: ../scraping/offres\Game_Development\Unreal Engine_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_30.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Cloud Security_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_23.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\Blockchain_job_1.txt, ../scraping/cvs\Blockchain\Blockchain_cv_36.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Kafka_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_56.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Data Science_job_1.txt, ../scraping/cvs\others\others_cv_158.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\AI Researcher_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_35.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\PostgreSQL_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_2.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Serverless_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_222.txt
# ⏩ Skipping already annotated: ../scraping/offres\Game_Development\C#_job_1.txt, ../scraping/cvs\Blockchain\Blockchain_cv_11.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\Solidity_job_1.txt, ../scraping/cvs\Blockchain\Blockchain_cv_37.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Spring_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_44.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Cloud Security_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_5.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Python Data Science_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_14.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Ruby on Rails_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_93.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Data Engineer_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_9.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Malware_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_30.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Kubernetes_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_3.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\C#_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_110.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Data Pipeline_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_23.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Git_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_23.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\Database Performance Tuning_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_6.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Ethical Hacking_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_23.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Reinforcement Learning_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_20.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\Cryptocurrency_job_1.txt, ../scraping/cvs\others\others_cv_215.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\PHP_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_14.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Infrastructure as Code_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_65.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Swift_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_4.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\SIEM_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_22.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\HTML_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_12.txt
# ⏩ Skipping already annotated: ../scraping/offres\Game_Development\C++_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_33.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Routing_job_1.txt, ../scraping/cvs\others\others_cv_220.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Cybersecurity_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_12.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\JavaScript_job_1.txt, ../scraping/cvs\others\others_cv_93.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Penetration Testing_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_61.txt
# ⏩ Skipping already annotated: ../scraping/offres\Technical_Support\Windows Server_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_93.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Matplotlib_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_5.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\DeFi_job_1.txt, ../scraping/cvs\Blockchain\Blockchain_cv_20.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\MongoDB_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_25.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Data Warehousing_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_76.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\SQL_job_1.txt, ../scraping/cvs\others\others_cv_105.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Reinforcement Learning_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_191.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\Data Backup_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_31.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Docker_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_4.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Malware_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_25.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Infrastructure as Code_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_68.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Firewall_job_1.txt, ../scraping/cvs\others\others_cv_183.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Symfony_job_1.txt, ../scraping/cvs\others\others_cv_117.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\Oracle_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_22.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\Xcode_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_126.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Django_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_158.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\Android Studio_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_99.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\NoSQL_job_1.txt, ../scraping/cvs\others\others_cv_277.txt
# ⏩ Skipping already annotated: ../scraping/offres\Game_Development\Mobile Game Development_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_57.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Apache Spark_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_86.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Google Cloud_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_27.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\Data Migration_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_22.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Smart Devices_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_127.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Big Data_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_8.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Cybersecurity_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_22.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\Flutter_job_1.txt, ../scraping/cvs\machine_learning\cv_ml_3.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\App Development_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_27.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Angular_job_1.txt, ../scraping/cvs\others\others_cv_111.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Express.js_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_23.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Arduino_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_3.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Incident Response_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_74.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Pandas_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_6.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Kotlin_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_97.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Apache Spark_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_24.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Keras_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_121.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Vue.js_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_25.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\Android Studio_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_23.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\TCP_IP_job_1.txt, ../scraping/cvs\others\others_cv_269.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\CSS_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_32.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Performance_job_1.txt, ../scraping/cvs\Blockchain\Blockchain_cv_8.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Node.js_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_22.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\TensorFlow_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_2.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Security_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_161.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Rust_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_4.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\Solidity_job_1.txt, ../scraping/cvs\Blockchain\Blockchain_cv_19.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\Android_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_79.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Reinforcement Learning_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_64.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Terraform_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_89.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\SQL_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_124.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Vue.js_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_6.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\SIEM_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_85.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\Xcode_job_1.txt, ../scraping/cvs\others\others_cv_190.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Docker_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_52.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Seaborn_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_102.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Laravel_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_18.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\App Development_job_1.txt, ../scraping/cvs\others\others_cv_150.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\Blockchain Developer_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_80.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Edge Computing_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_146.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Wireless Networks_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_86.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\JQuery_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_32.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Apache Spark_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_13.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Neural Networks_job_1.txt, ../scraping/cvs\others\others_cv_109.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Data Warehousing_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_46.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Cloud DevOps_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_58.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Embedded Systems_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_6.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\NoSQL_job_1.txt, ../scraping/cvs\others\others_cv_304.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Matplotlib_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_23.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Flask_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_10.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\IoT Platforms_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_63.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\CI CD_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_25.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Smart Devices_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_23.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Juniper_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_6.txt
# ⏩ Skipping already annotated: ../scraping/offres\Game_Development\3D Modeling_job_1.txt, ../scraping/cvs\others\others_cv_183.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Data Analyst_job_1.txt, ../scraping/cvs\others\others_cv_313.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\JavaScript_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_84.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Docker_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_30.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Node.js_job_1.txt, ../scraping/cvs\others\others_cv_296.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Python Software Development_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_13.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Troubleshooting_job_1.txt, ../scraping/cvs\others\others_cv_38.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\CI CD_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_20.txt
# ⏩ Skipping already annotated: ../scraping/offres\Game_Development\Mobile Game Development_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_42.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\PyTorch_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_52.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\iOS_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_61.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\AI Engineer_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_68.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Docker_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_62.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\TensorFlow_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_50.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Numpy_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_48.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Wireless Networks_job_1.txt, ../scraping/cvs\others\others_cv_200.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Spark_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_30.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\CI CD_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_39.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Serverless_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_43.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Linux_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_11.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\NFTs_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_301.txt
# ⏩ Skipping already annotated: ../scraping/offres\Technical_Support\Linux Server_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_188.txt
# ⏩ Skipping already annotated: ../scraping/offres\Technical_Support\Active Directory_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_4.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Automation_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_10.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Neural Networks_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_14.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Cybersecurity_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_26.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\Database Security_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_285.txt
# ⏩ Skipping already annotated: ../scraping/offres\Technical_Support\Troubleshooting_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_12.txt
# ⏩ Skipping already annotated: ../scraping/offres\Technical_Support\Technical Support_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_36.txt
# ⏩ Skipping already annotated: ../scraping/offres\Game_Development\Game AI_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_41.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\Android_job_1.txt, ../scraping/cvs\others\others_cv_163.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Security Operations Center_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_18.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Juniper_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_62.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Hadoop_job_1.txt, ../scraping/cvs\others\others_cv_289.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Supervised Learning_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_18.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\ETL_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_36.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Laravel_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_30.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Malware_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_17.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\NoSQL_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_26.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Artificial Intelligence_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_63.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Seaborn_job_1.txt, ../scraping/cvs\others\others_cv_293.txt
# ⏩ Skipping already annotated: ../scraping/offres\Game_Development\Game Programming_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_31.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Security_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_19.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Kafka_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_26.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\GraphQL_job_1.txt, ../scraping/cvs\Blockchain\Blockchain_cv_20.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\Android Development_job_1.txt, ../scraping/cvs\machine_learning\cv_ml_10.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\PostgreSQL_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_27.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\React_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_270.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Ransomware_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_1.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Rust_job_1.txt, ../scraping/cvs\others\others_cv_366.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Data Engineering_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_53.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\MySQL_job_1.txt, ../scraping/cvs\others\others_cv_254.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\CI CD_job_1.txt, ../scraping/cvs\others\others_cv_9.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\App Development_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_114.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\Database Administration_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_22.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\PostgreSQL_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_138.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Kotlin_job_1.txt, ../scraping/cvs\others\others_cv_200.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Laravel_job_1.txt, ../scraping/cvs\others\others_cv_58.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Deep Learning_job_1.txt, ../scraping/cvs\others\others_cv_247.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\Swift_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_298.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\AI Engineer_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_70.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\Data Recovery_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_140.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Raspberry Pi_job_1.txt, ../scraping/cvs\others\others_cv_49.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Internet of Things_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_36.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\AWS Lambda_job_1.txt, ../scraping/cvs\others\others_cv_367.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Terraform_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_274.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Big Data_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_36.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\Mobile Apps_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_123.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Supervised Learning_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_58.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Design_job_1.txt, ../scraping/cvs\others\others_cv_225.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\Bitcoin_job_1.txt, ../scraping/cvs\Blockchain\Blockchain_cv_31.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Pandas_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_83.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Go_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_73.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\TypeScript_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_15.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Machine Learning_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_98.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\CI CD_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_217.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Data Mining_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_32.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\Smart Contracts_job_1.txt, ../scraping/cvs\others\others_cv_258.txt
# ⏩ Skipping already annotated: ../scraping/offres\Mobile_Development\iOS Development_job_1.txt, ../scraping/cvs\others\others_cv_79.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Flask_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_69.txt
# ⏩ Skipping already annotated: ../scraping/offres\Technical_Support\Active Directory_job_1.txt, ../scraping/cvs\others\others_cv_310.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\React_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_229.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Jenkins_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_145.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\NoSQL_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_58.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\SQL_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_23.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\Laravel_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_274.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Data Lakes_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_44.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Monitoring_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_122.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Deep Learning_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_53.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Science\Data Engineer_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_118.txt
# ⏩ Skipping already annotated: ../scraping/offres\Game_Development\Game Design_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_1.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Shell Scripting_job_1.txt, ../scraping/cvs\Data_Engineering\Data_Engineering_cv_45.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Ansible_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_53.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\Machine Learning_job_1.txt, ../scraping/cvs\others\others_cv_20.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Protocols_job_1.txt, ../scraping/cvs\others\others_cv_183.txt
# ⏩ Skipping already annotated: ../scraping/offres\Data_Engineering\Data Warehousing_job_1.txt, ../scraping/cvs\AI_and_ML\AI_and_ML_cv_6.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Vulnerability Assessment_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_10.txt
# ⏩ Skipping already annotated: ../scraping/offres\AI_and_ML\TensorFlow_job_1.txt, ../scraping/cvs\others\others_cv_301.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Git_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_96.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Python Software Development_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_82.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\PostgreSQL_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_20.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Git_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_222.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Linux_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_21.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Linux_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_29.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\SQL_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_20.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\MongoDB_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_27.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\Blockchain Architect_job_1.txt, ../scraping/cvs\Web_Development\Web_Development_cv_11.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\MySQL_job_1.txt, ../scraping/cvs\others\others_cv_206.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Security Operations Center_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_155.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Smart Devices_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_52.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\C#_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_74.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cybersecurity\Incident Response_job_1.txt, ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_1.txt
# ⏩ Skipping already annotated: ../scraping/offres\Game_Development\C#_job_1.txt, ../scraping/cvs\others\others_cv_379.txt
# ⏩ Skipping already annotated: ../scraping/offres\Web_Development\SQL_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_2.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Security_job_1.txt, ../scraping/cvs\others\others_cv_334.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\Blockchain Solutions_job_1.txt, ../scraping/cvs\Blockchain\Blockchain_cv_26.txt
# ⏩ Skipping already annotated: ../scraping/offres\Database_Administration\MongoDB_job_1.txt, ../scraping/cvs\Database_Administration\Database_Administration_cv_18.txt
# ⏩ Skipping already annotated: ../scraping/offres\IoT\Wireless Networks_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_239.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Swift_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_305.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\C++_job_1.txt, ../scraping/cvs\others\others_cv_280.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Vue.js_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_176.txt
# ⏩ Skipping already annotated: ../scraping/offres\Software_Development\Laravel_job_1.txt, ../scraping/cvs\Software_Development\Software_Development_cv_216.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Engineer_job_1.txt, ../scraping/cvs\others\others_cv_166.txt
# ⏩ Skipping already annotated: ../scraping/offres\Blockchain\Blockchain Architect_job_1.txt, ../scraping/cvs\others\others_cv_117.txt
# ⏩ Skipping already annotated: ../scraping/offres\Cloud_Computing\Azure_job_1.txt, ../scraping/cvs\Data_Science\Data_Science_cv_119.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Git_job_1.txt, ../scraping/cvs\Cybersecurity\Cybersecurity_cv_4.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Routing_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_36.txt
# ⏩ Skipping already annotated: ../scraping/offres\Networking\Network Engineer_job_1.txt, ../scraping/cvs\others\others_cv_129.txt
# ⏩ Skipping already annotated: ../scraping/offres\DevOps\Kubernetes_job_1.txt, ../scraping/cvs\DevOps\DevOps_cv_102.txt
#
# 🔎 Offer: ../scraping/offres\Data_Science\Keras_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_80.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Software_Development\DevOps_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_293.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\AI Researcher_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_19.txt
# ✅ Score obtenu : 0.22
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Technical_Support\Ticketing Systems_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_46.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Database_Administration\Oracle_job_1.txt
# 📝 CV: ../scraping/cvs\Database_Administration\Database_Administration_cv_10.txt
# ✅ Score obtenu : 0.72
#
# 🔎 Offer: ../scraping/offres\Technical_Support\Technical Documentation_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_21.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\Unsupervised Learning_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_49.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Cloud_Computing\Azure_job_1.txt
# 📝 CV: ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_1.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\DevOps\DevOps_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_24.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Technical_Support\Customer Support_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_136.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Blockchain\Blockchain Solutions_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_47.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\Machine Learning_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_8.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Data_Engineering\Data Pipeline_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_131.txt
# ✅ Score obtenu : 0.2
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Blockchain\DeFi_job_1.txt
# 📝 CV: ../scraping/cvs\Blockchain\Blockchain_cv_7.txt
# ✅ Score obtenu : 0.7
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\PyTorch_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_11.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Risk Management_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_85.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\Game_Development\Mobile Game Development_job_1.txt
# 📝 CV: ../scraping/cvs\Web_Development\Web_Development_cv_17.txt
# ✅ Score obtenu : 0.23
#
# 🔎 Offer: ../scraping/offres\Technical_Support\Windows Server_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_36.txt
# Error: 429 {"error":{"message":"Rate limit reached for model `llama3-8b-8192` in organization `org_01jsspqaaef6gagkgxztv5p1hz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 3695, Requested 2547. Please try again in 2.42s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
# ⏳ Erreur 429 : Attente avant réessai...
# 🕒 Temps d'attente avant réessai : 18 secondes
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Blockchain\Ethereum_job_1.txt
# 📝 CV: ../scraping/cvs\Blockchain\Blockchain_cv_18.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\Data_Science\Data Mining_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_139.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Networking\TCP_IP_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_17.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Database_Administration\MySQL_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_59.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\DevOps\Cloud Automation_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_165.txt
# ✅ Score obtenu : 0.25
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\IoT\Smart Devices_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_71.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Blockchain\Blockchain Solutions_job_1.txt
# 📝 CV: ../scraping/cvs\Blockchain\Blockchain_cv_31.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\Natural Language Processing_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_171.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Data_Science\Numpy_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_169.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Firewall_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_313.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Data_Engineering\Data Lakes_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_68.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\Networking\Network Administration_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_59.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Data_Science\Hadoop_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_16.txt
# ✅ Score obtenu : 0.23
#
# 🔎 Offer: ../scraping/offres\Cloud_Computing\AWS_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_67.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Mobile_Development\Mobile Apps_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_43.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Data_Science\TensorFlow_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_267.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Data_Engineering\SQL_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_41.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\IoT\Embedded Systems_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_18.txt
# ✅ Score obtenu : 0.23
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Ethical Hacking_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_117.txt
# Error: 429 {"error":{"message":"Rate limit reached for model `llama3-8b-8192` in organization `org_01jsspqaaef6gagkgxztv5p1hz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 3740, Requested 3002. Please try again in 7.415999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
# ⏳ Erreur 429 : Attente avant réessai...
# 🕒 Temps d'attente avant réessai : 18 secondes
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Blockchain\Cryptocurrency_job_1.txt
# 📝 CV: ../scraping/cvs\Blockchain\Blockchain_cv_20.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Software_Development\Git_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_223.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\Networking\Cisco_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_150.txt
# ✅ Score obtenu : 0.23
#
# 🔎 Offer: ../scraping/offres\Blockchain\Cryptocurrency_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_314.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Web_Development\Django_job_1.txt
# 📝 CV: ../scraping/cvs\Web_Development\Web_Development_cv_18.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Software_Development\TDD_job_1.txt
# 📝 CV: ../scraping/cvs\Cybersecurity\Cybersecurity_cv_2.txt
# ✅ Score obtenu : 0.15
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Data_Science\Seaborn_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_20.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Cloud_Computing\Ansible_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_109.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Blockchain\Smart Contracts_job_1.txt
# 📝 CV: ../scraping/cvs\Blockchain\Blockchain_cv_9.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Technical_Support\Windows Server_job_1.txt
# 📝 CV: ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_25.txt
# Error: 429 {"error":{"message":"Rate limit reached for model `llama3-8b-8192` in organization `org_01jsspqaaef6gagkgxztv5p1hz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 4006, Requested 3128. Please try again in 11.333s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
# ⏳ Erreur 429 : Attente avant réessai...
# 🕒 Temps d'attente avant réessai : 18 secondes
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Game_Development\Game Programming_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_64.txt
# ✅ Score obtenu : 0.15
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Game_Development\3D Modeling_job_1.txt
# 📝 CV: ../scraping/cvs\Web_Development\Web_Development_cv_13.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\Mobile_Development\Android Development_job_1.txt
# 📝 CV: ../scraping/cvs\Web_Development\Web_Development_cv_10.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\IoT\IoT_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_99.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Web_Development\Angular_job_1.txt
# 📝 CV: ../scraping/cvs\Web_Development\Web_Development_cv_27.txt
# ✅ Score obtenu : 0.35
#
# 🔎 Offer: ../scraping/offres\Blockchain\Cryptography_job_1.txt
# 📝 CV: ../scraping/cvs\Blockchain\Blockchain_cv_36.txt
# ✅ Score obtenu : 0.2
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\TensorFlow_job_1.txt
# 📝 CV: ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_32.txt
# ✅ Score obtenu : 0.23
#
# 🔎 Offer: ../scraping/offres\Networking\Network Protocols_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_82.txt
# ✅ Score obtenu : 0.1
#
# 🔎 Offer: ../scraping/offres\Software_Development\Kotlin_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_21.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\IoT\IoT Security_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_50.txt
# ✅ Score obtenu : 0.25
#
# 🔎 Offer: ../scraping/offres\Data_Science\Big Data_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_62.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Incident Response_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_11.txt
# ✅ Score obtenu : 0.23
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\Machine Learning_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_40.txt
# Error: 429 {"error":{"message":"Rate limit reached for model `llama3-8b-8192` in organization `org_01jsspqaaef6gagkgxztv5p1hz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 3457, Requested 3195. Please try again in 6.515999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
# ⏳ Erreur 429 : Attente avant réessai...
# 🕒 Temps d'attente avant réessai : 18 secondes
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Web_Development\Express.js_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_336.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Database_Administration\Data Migration_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_56.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Blockchain\Blockchain Developer_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_30.txt
# ✅ Score obtenu : 0.05
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Blockchain\NFTs_job_1.txt
# 📝 CV: ../scraping/cvs\Blockchain\Blockchain_cv_26.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\Web_Development\GraphQL_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_189.txt
# Error: 429 {"error":{"message":"Rate limit reached for model `llama3-8b-8192` in organization `org_01jsspqaaef6gagkgxztv5p1hz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 3082, Requested 3059. Please try again in 1.408s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
# ⏳ Erreur 429 : Attente avant réessai...
# 🕒 Temps d'attente avant réessai : 18 secondes
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Technical_Support\IT Support_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_13.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Data_Science\TensorFlow_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_19.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Ethical Hacking_job_1.txt
# 📝 CV: ../scraping/cvs\Blockchain\Blockchain_cv_22.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Web_Development\GraphQL_job_1.txt
# 📝 CV: ../scraping/cvs\Web_Development\Web_Development_cv_5.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Web_Development\Angular_job_1.txt
# 📝 CV: ../scraping/cvs\Web_Development\Web_Development_cv_19.txt
# ✅ Score obtenu : 0.22
#
# 🔎 Offer: ../scraping/offres\Data_Science\Python Data Science_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_98.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Network Security_job_1.txt
# 📝 CV: ../scraping/cvs\Database_Administration\Database_Administration_cv_7.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Ransomware_job_1.txt
# 📝 CV: ../scraping/cvs\Cybersecurity\Cybersecurity_cv_15.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Software_Development\TDD_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_290.txt
# ✅ Score obtenu : 0.2
#
# 🔎 Offer: ../scraping/offres\Database_Administration\Data Migration_job_1.txt
# 📝 CV: ../scraping/cvs\Database_Administration\Database_Administration_cv_1.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Data_Engineering\SQL_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_96.txt
# ✅ Score obtenu : 0.25
#
# 🔎 Offer: ../scraping/offres\Web_Development\SQL_job_1.txt
# 📝 CV: ../scraping/cvs\Web_Development\Web_Development_cv_10.txt
# ✅ Score obtenu : 0.2
#
# 🔎 Offer: ../scraping/offres\Game_Development\Unity_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_49.txt
# ✅ Score obtenu : 0.1
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Blockchain\Ethereum_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_34.txt
# ✅ Score obtenu : 0.2
#
# 🔎 Offer: ../scraping/offres\Web_Development\Vue.js_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_1.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Data_Science\SQL_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_81.txt
# ✅ Score obtenu : 0.62
#
# 🔎 Offer: ../scraping/offres\Software_Development\Symfony_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_94.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Malware_job_1.txt
# 📝 CV: ../scraping/cvs\Cybersecurity\Cybersecurity_cv_4.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Data_Engineering\NoSQL_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_53.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\IoT\Smart Home_job_1.txt
# 📝 CV: ../scraping/cvs\Cybersecurity\Cybersecurity_cv_6.txt
# ✅ Score obtenu : 0.32
#
# 🔎 Offer: ../scraping/offres\Web_Development\Django_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_253.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Cloud_Computing\Docker_job_1.txt
# 📝 CV: ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_7.txt
# ✅ Score obtenu : 0.35
#
# 🔎 Offer: ../scraping/offres\Blockchain\Ethereum Developer_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_11.txt
# ✅ Score obtenu : 0.2
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Mobile_Development\Mobile UX_UI_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_68.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\Deep Learning_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_279.txt
# ✅ Score obtenu : 0.2
#
# 🔎 Offer: ../scraping/offres\Cloud_Computing\CI CD_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_301.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\DevOps\Bash_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_96.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Networking\Firewall_job_1.txt
# 📝 CV: ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_25.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Data_Engineering\NoSQL_job_1.txt
# 📝 CV: ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_29.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Firewall_job_1.txt
# 📝 CV: ../scraping/cvs\Cybersecurity\Cybersecurity_cv_11.txt
# ✅ Score obtenu : 0.72
#
# 🔎 Offer: ../scraping/offres\Networking\Network Administration_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_110.txt
# ✅ Score obtenu : 0.22
#
# 🔎 Offer: ../scraping/offres\Networking\Network Engineer_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_122.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\AI Researcher_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_93.txt
# ✅ Score obtenu : 0.12
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Software_Development\Symfony_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_246.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Software_Development\DevOps_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_65.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Database_Administration\Data Migration_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_152.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Software_Development\DevOps_job_1.txt
# 📝 CV: ../scraping/cvs\Web_Development\Web_Development_cv_7.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Networking\VPN_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_229.txt
# ✅ Score obtenu : 0.12
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Data_Science\Spark_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_148.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Software_Development\Vue.js_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_67.txt
# Error: 429 {"error":{"message":"Rate limit reached for model `llama3-8b-8192` in organization `org_01jsspqaaef6gagkgxztv5p1hz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 3736, Requested 3169. Please try again in 9.045s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
# ⏳ Erreur 429 : Attente avant réessai...
# 🕒 Temps d'attente avant réessai : 18 secondes
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Software_Development\TypeScript_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_52.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\DevOps\AWS_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_6.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Data_Engineering\SQL_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_61.txt
# ✅ Score obtenu : 0.72
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Game_Development\Mobile Game Development_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_285.txt
# ✅ Score obtenu : 0.2
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Network Defense_job_1.txt
# 📝 CV: ../scraping/cvs\Cybersecurity\Cybersecurity_cv_2.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Web_Development\JQuery_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_104.txt
# ✅ Score obtenu : 0.2
#
# 🔎 Offer: ../scraping/offres\Technical_Support\Technical Support_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_42.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Data_Science\Data Science_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_14.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Technical_Support\Help Desk_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_100.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Software_Development\Vue.js_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_65.txt
# ✅ Score obtenu : 0.23
#
# 🔎 Offer: ../scraping/offres\Cloud_Computing\DevOps_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_185.txt
# Error: 429 {"error":{"message":"Rate limit reached for model `llama3-8b-8192` in organization `org_01jsspqaaef6gagkgxztv5p1hz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 4332, Requested 1842. Please try again in 1.732s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
# ⏳ Erreur 429 : Attente avant réessai...
# 🕒 Temps d'attente avant réessai : 18 secondes
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Networking\Network Performance_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_50.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Data_Science\Data Mining_job_1.txt
# 📝 CV: ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_13.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Technical_Support\IT Support_job_1.txt
# 📝 CV: ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_28.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Cryptography_job_1.txt
# 📝 CV: ../scraping/cvs\Cybersecurity\Cybersecurity_cv_20.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Database_Administration\NoSQL_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_78.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Game_Development\VR Development_job_1.txt
# 📝 CV: ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_29.txt
# ✅ Score obtenu : 0.23
#
# 🔎 Offer: ../scraping/offres\IoT\IoT Security_job_1.txt
# 📝 CV: ../scraping/cvs\Cloud_Computing\Cloud_Computing_cv_18.txt
# Error: 429 {"error":{"message":"Rate limit reached for model `llama3-8b-8192` in organization `org_01jsspqaaef6gagkgxztv5p1hz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 4232, Requested 1805. Please try again in 362.999999ms. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
# ⏳ Erreur 429 : Attente avant réessai...
# 🕒 Temps d'attente avant réessai : 18 secondes
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\IoT\Embedded Systems_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Engineering\Data_Engineering_cv_27.txt
# ✅ Score obtenu : 0.23
#
# 🔎 Offer: ../scraping/offres\Technical_Support\Technical Support_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_83.txt
# ✅ Score obtenu : 0.35
#
# 🔎 Offer: ../scraping/offres\Cloud_Computing\CI CD_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_179.txt
# ✅ Score obtenu : 0.25
#
# 🔎 Offer: ../scraping/offres\DevOps\CI CD_job_1.txt
# 📝 CV: ../scraping/cvs\DevOps\DevOps_cv_136.txt
# ✅ Score obtenu : 0.2
#
# 🔎 Offer: ../scraping/offres\Mobile_Development\Flutter_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_18.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\Artificial Intelligence_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_88.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Data_Science\Scikit-learn_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_90.txt
# ✅ Score obtenu : 0.23
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Penetration Testing_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_9.txt
# ✅ Score obtenu : 0.2
#
# 🔎 Offer: ../scraping/offres\Software_Development\Vue.js_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_179.txt
# ✅ Score obtenu : 0.2
#
# 🔎 Offer: ../scraping/offres\Software_Development\C++_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_124.txt
# ✅ Score obtenu : 0.12
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Web_Development\PostgreSQL_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_148.txt
# ✅ Score obtenu : 0.02
#
# 🔎 Offer: ../scraping/offres\Software_Development\Rust_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_152.txt
# ✅ Score obtenu : 0.05
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\AI Engineer_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_107.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Game_Development\VR Development_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_114.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\Software_Development\Java_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_247.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Blockchain\Bitcoin_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_106.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Cybersecurity_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_229.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Data_Science\AI_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_118.txt
# ✅ Score obtenu : 0.2
#
# 🔎 Offer: ../scraping/offres\Game_Development\Game AI_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_221.txt
# ✅ Score obtenu : 0.12
#
# 🔎 Offer: ../scraping/offres\Database_Administration\Data Backup_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_108.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Data_Engineering\Hadoop_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_58.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\DevOps\AWS Lambda_job_1.txt
# 📝 CV: ../scraping/cvs\Cybersecurity\Cybersecurity_cv_8.txt
# Error: 429 {"error":{"message":"Rate limit reached for model `llama3-8b-8192` in organization `org_01jsspqaaef6gagkgxztv5p1hz` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 4329, Requested 2284. Please try again in 6.120999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
# ⏳ Erreur 429 : Attente avant réessai...
# 🕒 Temps d'attente avant réessai : 18 secondes
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Data_Science\Hadoop_job_1.txt
# 📝 CV: ../scraping/cvs\Data_Science\Data_Science_cv_143.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\AI_and_ML\Data Scientist_job_1.txt
# 📝 CV: ../scraping/cvs\AI_and_ML\AI_and_ML_cv_86.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Cloud_Computing\CI CD_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_199.txt
# ✅ Score obtenu : 0.42
# 💾 Progress saved.
#
# 🔎 Offer: ../scraping/offres\Software_Development\Laravel_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_156.txt
# ✅ Score obtenu : 0.42
#
# 🔎 Offer: ../scraping/offres\Game_Development\3D Modeling_job_1.txt
# 📝 CV: ../scraping/cvs\others\others_cv_172.txt
# ✅ Score obtenu : 0.15
#
# 🔎 Offer: ../scraping/offres\Cybersecurity\Vulnerability Assessment_job_1.txt
# 📝 CV: ../scraping/cvs\Software_Development\Software_Development_cv_40.txt
# ✅ Score obtenu : 0.42
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 annotate_data(input_path="ready_to_annotate.csv",output_path="annotated_data2.csv",max_annotations=1000,api="groq")
#
# Cell In[4], line 66, in annotate_data(input_path, output_path, max_annotations, api)
#      63         print("💾 Progress saved.")
#      65     # Sleep randomly between 5 and 10 seconds to avoid API limits
# ---> 66     time.sleep(random.uniform(10, 15))
#      68 except Exception as e:
#      69     print(f"❌ Erreur lors de l’annotation : {e}")
#
# KeyboardInterrupt:

# %%
# 📚 1. Importations
import pandas as pd
from pathlib import Path

# 📂 2. Charger le CSV initial
df = pd.read_csv('annotated_data2.csv')  # Remplace par ton fichier existant

# 📄 3. Fonction pour lire un fichier texte
def read_text_file(path):
    try:
        with open(Path(path), 'r', encoding='utf-8') as f:
            return f.read()
    except Exception as e:
        print(f"Erreur lecture fichier {path}: {e}")
        return ""

# 🛠️ 4. Appliquer pour lire l'offre et le CV
df['offer_text'] = df['offer_path'].apply(read_text_file)
df['cv_text'] = df['cv_path'].apply(read_text_file)

# 🧹 5. Garder uniquement offer_text, cv_text, score
df_final = df[['offer_text', 'cv_text', 'score']]

# 💾 6. Sauvegarder dans data/data.csv
output_path = Path('../data/labeled_data.csv')
output_path.parent.mkdir(exist_ok=True)  # Créer dossier 'data' s'il n'existe pas
df_final.to_csv(output_path, index=False)

print("✅ Préparation terminée ! Fichier sauvegardé dans data/labled_data.csv")
# Out:
# Erreur lecture fichier ../scraping/cvs\machine_learning\cv_ml_3.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Erreur lecture fichier ../scraping/cvs\machine_learning\cv_ml_10.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# ✅ Préparation terminée ! Fichier sauvegardé dans data/labled_data.csv
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
